# %%
import pandas as pd

# %%
import plotly.express as px

# %%
lagos = pd.read_csv("lagos_arg.csv")

# %%
lagos
# Out:
#                     Nombre                                          Ubicación  \
# 0           Lago Argentino                                         Santa Cruz
# 1              Lago Viedma                                         Santa Cruz
# 2        Lago Nahuel Huapi                                Río Negro / Neuquén
# 3             Lago Musters                                             Chubut
# 4             Lago Cardiel                                         Santa Cruz
# 5             Lago Epecuén                                       Buenos Aires
# 6          Lago Pellegrini                                          Río Negro
# 7             Lago Strobel                                         Santa Cruz
# 8             Lago Fontana                                             Chubut
# 9       Lago Huechulafquen                                            Neuquén
# 10             Lago Traful                                            Neuquén
# ...

# %% [markdown]
# ¿Qué columnas tienen valores categorizados que permiten calcular frecuencias con value_counts?

# %%
dataset = pd.read_csv("lagos_arg.csv")
print(dataset["Ubicación"].value_counts())
# Out:
# Ubicación
# Santa Cruz                                                 16
# Neuquén                                                    14
# Chubut                                                     13
# Río Negro                                                   4
# Río Negro / Neuquén                                         1
# Buenos Aires                                                1
# Tierra del Fuego,\n Antártida e Islas del Atlántico Sur     1
# Tierra del Fuego, Antártida e Islas del Atlántico Sur\n     1
# Tierra del Fuego, Antártida e Islas del Atlántico Sur       1
# Name: count, dtype: int64

# %%
print(dataset["Sup Tamaño"].value_counts())
# Out:
# Sup Tamaño
# medio     25
# chico     14
# grande    13
# Name: count, dtype: int64

# %%
lagos = pd.read_csv("lagos_arg.csv")

# %%
dataset = pd.read_csv("lagos_arg.csv")

# %% [markdown]
# ¿Qué diferencia hay entre las columnas?

# %% [markdown]
# La diferencia es que coordenadas es un dato que tiene en si de LAT y LNG en GMS. Lat en GMS es latitud en GRADOS MINUTOS y SEGUNDOS. Longitud  en GMS es longitud en GRADOS MINUTOS y SEGUNDOS. Despues lat y long en decimales.

# %%
print(dataset.head(10))
# Out:
#                Nombre            Ubicación  Superficie (km²)  \
# 0      Lago Argentino           Santa Cruz              1435
# 1         Lago Viedma           Santa Cruz              1166
# 2   Lago Nahuel Huapi  Río Negro / Neuquén               540
# 3        Lago Musters               Chubut               427
# 4        Lago Cardiel           Santa Cruz               358
# 5        Lago Epecuén         Buenos Aires               156
# 6     Lago Pellegrini            Río Negro               116
# 7        Lago Strobel           Santa Cruz               100
# 8        Lago Fontana               Chubut                84
# 9  Lago Huechulafquen              Neuquén                84
#
#    Profundidad máxima (m)  Profundidad media (m)            Coordenadas  \
# 0                   500.0                  150.0  50°14'53"S 72°38'43"O
# 1                     NaN                    NaN  49°37'27"S 72°29'42"O
# 2                   464.0                  157.0  40°51'16"S 71°36'58"O
# ...

# %% [markdown]
# ¿Qué columnas tienen datos faltantes?

# %% [markdown]
# Respuesta: Profundidad media (faltan 30), Profundidad máxima (faltan 37) .isnull().sum() te da los datos que estan vacios (la cantidad) y el .info te da los datos que estan con algun contenido (no nulos).

# %%
print(dataset.info())
print(dataset.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Nombre                  52 non-null     str
#  1   Ubicación               52 non-null     str
#  2   Superficie (km²)        52 non-null     int64
#  3   Profundidad máxima (m)  15 non-null     float64
#  4   Profundidad media (m)   22 non-null     float64
#  5   Coordenadas             52 non-null     str
#  6   Sup Tamaño              52 non-null     str
#  7   Latitud en GMS          52 non-null     str
#  8   Longitud en GMS         52 non-null     str
#  9   lat                     52 non-null     float64
#  10  lng                     52 non-null     float64
# dtypes: float64(4), int64(1), str(6)
# memory usage: 4.6 KB
# None
# Nombre                     0
# Ubicación                  0
# Superficie (km²)           0
# Profundidad máxima (m)    37
# ...

# %% [raw]
# Parte 1.1

# %% [markdown]
# ¿Cuáles son los nombres de las columnas?

# %%
print(dataset.columns)
# Out:
# Index(['Nombre', 'Ubicación', 'Superficie (km²)', 'Profundidad máxima (m)',
#        'Profundidad media (m)', 'Coordenadas', 'Sup Tamaño', 'Latitud en GMS',
#        'Longitud en GMS', 'lat', 'lng'],
#       dtype='str')

# %% [markdown]
# ¿Qué tipos de datos tiene cada columna?

# %%
print(dataset.dtypes)
# Out:
# Nombre                        str
# Ubicación                     str
# Superficie (km²)            int64
# Profundidad máxima (m)    float64
# Profundidad media (m)     float64
# Coordenadas                   str
# Sup Tamaño                    str
# Latitud en GMS                str
# Longitud en GMS               str
# lat                       float64
# lng                       float64
# dtype: object

# %% [markdown]
# Muestra las primeras 5 filas del dataset.

# %%
print(dataset.head(5))
# Out:
#               Nombre            Ubicación  Superficie (km²)  \
# 0     Lago Argentino           Santa Cruz              1435
# 1        Lago Viedma           Santa Cruz              1166
# 2  Lago Nahuel Huapi  Río Negro / Neuquén               540
# 3       Lago Musters               Chubut               427
# 4       Lago Cardiel           Santa Cruz               358
#
#    Profundidad máxima (m)  Profundidad media (m)            Coordenadas  \
# 0                   500.0                  150.0  50°14'53"S 72°38'43"O
# 1                     NaN                    NaN  49°37'27"S 72°29'42"O
# 2                   464.0                  157.0  40°51'16"S 71°36'58"O
# 3                    39.0                   20.0  45°24'53"S 69°11'52"O
# 4                     NaN                   49.0   48°55'3"S 71°12'53"O
#
#   Sup Tamaño Latitud en GMS Longitud en GMS        lat           lng
# 0     grande     50°14'53"S      72°38'43"O -50.248056    -72.645278
# ...

# %% [markdown]
# ¿Cuántos lagos hay en la provincia de Santa Cruz?

# %%
filtro_1 = dataset[dataset["Ubicación"] == "Santa Cruz"]
print(filtro_1["Ubicación"].value_counts())
# Out:
# Ubicación
# Santa Cruz    16
# Name: count, dtype: int64

# %% [markdown]
# ¿Cuántos lagos hay en cada provincia?

# %%
print(dataset["Ubicación"].value_counts())
# Out:
# Ubicación
# Santa Cruz                                                 16
# Neuquén                                                    14
# Chubut                                                     13
# Río Negro                                                   4
# Río Negro / Neuquén                                         1
# Buenos Aires                                                1
# Tierra del Fuego,\n Antártida e Islas del Atlántico Sur     1
# Tierra del Fuego, Antártida e Islas del Atlántico Sur\n     1
# Tierra del Fuego, Antártida e Islas del Atlántico Sur       1
# Name: count, dtype: int64

# %% [markdown]
# Crea un gráfico que compare las cantidades de lagos por provincia.

# %%
filtro_1 = dataset["Ubicación"].value_counts()
var_1=px.bar(data_frame=filtro_1, x = filtro_1.values, y = filtro_1.index, title = "var1")
var_1.show()

# %% [markdown]
# Filtra los lagos que pertenecen a la provincia de Neuquén. ¿falta algún lago de Nequén en el
# filtro?

# %%
filtro_1 = dataset[dataset["Ubicación"] == "Neuquén"]
print(filtro_1)
# Out:
#                 Nombre Ubicación  Superficie (km²)  Profundidad máxima (m)  \
# 9   Lago Huechulafquen   Neuquén                84                     NaN
# 10         Lago Traful   Neuquén                78                     NaN
# 14        Lago Aluminé   Neuquén                58                   165.0
# 15          Lago Lácar   Neuquén                53                   277.0
# 23         Lago Espejo   Neuquén                40                     NaN
# 27          Lago Lolog   Neuquén                37                     NaN
# 29         Lago Tromen   Neuquén                29                     NaN
# 31        Lago Quillén   Neuquén                26                     NaN
# 34       Lago Moquehue   Neuquén                21                     NaN
# 35     Lago Correntoso   Neuquén                20                     NaN
# 41         Lago Paimún   Neuquén                16                     NaN
# ...

# %% [markdown]
# Filtra los lagos de Chubut con superficie menor a 100 km2.

# %%
filtro_1 = dataset[dataset["Ubicación"] == "Chubut"]
filtro_2 = filtro_1[filtro_1["Superficie (km²)"] < 100]
print(filtro_2["Ubicación"].value_counts())
# Out:
# Ubicación
# Chubut    12
# Name: count, dtype: int64

# %% [markdown]
# ¿Cuántos valores nulos hay en la columna "Profundidad máxima (m)"?

# %%
print(dataset["Profundidad máxima (m)"].isnull().sum())
# Out:
# 37

# %% [markdown]
# Filtra los lagos de Chubut con profundidad máxima mayor a 100 m. ¿Esa cantidad de lagos
# informada es sobre todos los lagos de Chubut? ¿cuántos lagos son de Chubut y cuántos
# tienen datos en la columna de profundidad máxima?

# %%
filtro_1 = dataset[dataset["Ubicación"] == "Chubut"]
filtro_2 = filtro_1[filtro_1["Profundidad máxima (m)"] > 100]
print(filtro_1.info())
print(filtro_2)
# Out:
# <class 'pandas.DataFrame'>
# Index: 13 entries, 3 to 51
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Nombre                  13 non-null     str
#  1   Ubicación               13 non-null     str
#  2   Superficie (km²)        13 non-null     int64
#  3   Profundidad máxima (m)  8 non-null      float64
#  4   Profundidad media (m)   9 non-null      float64
#  5   Coordenadas             13 non-null     str
#  6   Sup Tamaño              13 non-null     str
#  7   Latitud en GMS          13 non-null     str
#  8   Longitud en GMS         13 non-null     str
#  9   lat                     13 non-null     float64
#  10  lng                     13 non-null     float64
# dtypes: float64(4), int64(1), str(6)
# memory usage: 1.2 KB
# None
#                Nombre Ubicación  Superficie (km²)  Profundidad máxima (m)  \
# ...

# %% [markdown]
# Crea un gráfico que compare los porcentajes de lagos según la categoría de tamaño.

# %%
filtro_1 = dataset["Sup Tamaño"].value_counts()
var_1=px.pie(data_frame = filtro_1, values = filtro_1.values, names = filtro_1.index, title =
"")
var_1.show()

# %%
import folium

# %%
def generar_mapa():
    attr = (
        '&copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> '
        'contributors, &copy; <a href="https://cartodb.com/attributions">CartoDB</a>'
    )
    
    tiles = 'https://wms.ign.gob.ar/geoserver/gwc/service/tms/1.0.0/capabaseargenmap@EPSG%3A3857@png/{z}/{x}/{-y}.png'
    m = folium.Map(
        location=(-33.457606, -65.346857),
        control_scale=True,
        zoom_start=5,
        name='es',
        tiles=tiles,
        attr=attr
    )
    return m

# %%
mapa=generar_mapa()
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
def agregar_marca_lago(row):
    folium.Marker(
        [row['lat'], row['lng']],
        popup=row['Ubicación'],
        icon=folium.Icon()
        ).add_to(mapa)

# %%
dataset.apply(agregar_marca_lago, axis=1)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
